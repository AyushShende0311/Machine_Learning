# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
country = []
date = []
stars = []
reviews = []

# %% [markdown]
# Scraping these values from the website

# %%
for i in range(1,37):
    page = requests.get(f'https://www.airlinequality.com/airline-reviews/british-airways/page/{i}/?sortby=post_date%3ADesc&pagesize=100')
    soup = BeautifulSoup(page.content,'lxml')
    for item in soup.find_all('div',class_='text_content'):
        reviews.append(item.text)
    
    for item in soup.find_all('div',class_ = 'rating-10'):
        try:
            stars.append(item.span.text)
        except:
            print(f"not found stars in page{i}")
    
    for item in soup.find_all('time'):
        date.append(item.text)
    
    
    for item in soup.find_all('h3'):
        country.append(item.span.next_sibling.text.strip(" ()"))
# Out:
# not found stars in page31
# not found stars in page32
# not found stars in page33
# not found stars in page35
# not found stars in page35

# %%
len(reviews)
# Out:
# 3600

# %%
len(date)
# Out:
# 3600

# %%
len(country)
# Out:
# 3600

# %%
len(stars)
# Out:
# 3600

# %%
#as there are some extra stars so to make them equal to the other columns
stars = stars[:3600]

# %%
df = pd.DataFrame({"reviews":reviews,"Date":date,"Country":country,"Stars":stars})

# %%
df.head()
# Out:
#                                              reviews              Date  \
# 0  ✅ Trip Verified |  Easy check in a T5. Galleri...  13th August 2023
# 1  Not Verified |  Flight delayed by an hour, it ...  12th August 2023
# 2  Not Verified | The staff are very rude and not...  11th August 2023
# 3  ✅ Trip Verified |  Good domestic flight operat...   8th August 2023
# 4  Not Verified | Failed at all basic travel fund...   8th August 2023
#
#           Country                          Stars
# 0  United Kingdom  \n\t\t\t\t\t\t\t\t\t\t\t\t\t5
# 1   United States                              8
# 2  United Kingdom                              2
# 3  United Kingdom                              2
# 4          Canada                             10

# %%
df.shape
# Out:
# (3600, 4)

# %% [markdown]
# Exporting them to the csv for further analysis

# %%
import os
cwd = os.getcwd()
df.to_csv(cwd+"/reviews.csv")
